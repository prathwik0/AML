# %%
import requests
from datetime import datetime, timedelta

def get_weather_data(api_key, city):
    end_date = datetime.now().strftime("%Y-%m-%d")
    start_date = (datetime.now() - timedelta(days=10)).strftime("%Y-%m-%d")

    base_url = f"http://api.weatherapi.com/v1/history.json?key={api_key}&q={city}&dt={start_date}&end_dt={end_date}"
    response = requests.get(base_url)
    data = response.json()

    if "error" in data:
        print(f"Error occurred: {data['error']['message']}")
    else:
        forecast_days = data["forecast"]["forecastday"]
        for day in forecast_days:
            date = day["date"]
            temperature = day["day"]["avgtemp_c"]
            humidity = day["day"]["avghumidity"]
            weather_description = day["day"]["condition"]["text"]

            # Print the weather information for each day
            print(f"Weather in {city} on {date}:")
            print(f"Temperature: {temperature}°C")
            print(f"Humidity: {humidity}%")
            print(f"Weather description: {weather_description}")
            print("-----------------------")

# API key for WeatherAPI (replace with your own key)
api_key = "8779"

# City for which you want to fetch weather data
city = "Karkala"

# Call the function to get weather data
get_weather_data(api_key, city)
# Out:
# Weather in Karkala on 2023-05-17:
# Temperature: 30.9°C
# Humidity: 68.0%
# Weather description: Partly cloudy
# -----------------------
# Weather in Karkala on 2023-05-18:
# Temperature: 30.8°C
# Humidity: 69.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-05-19:
# Temperature: 30.4°C
# Humidity: 69.0%
# Weather description: Partly cloudy
# -----------------------
# Weather in Karkala on 2023-05-20:
# Temperature: 30.5°C
# Humidity: 70.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-05-21:
# Temperature: 30.6°C
# Humidity: 69.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-05-22:
# Temperature: 29.6°C
# Humidity: 73.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-05-23:
# Temperature: 29.8°C
# Humidity: 75.0%
# Weather description: Patchy light rain with thunder
# -----------------------
# Weather in Karkala on 2023-05-24:
# Temperature: 28.8°C
# Humidity: 77.0%
# Weather description: Patchy light rain with thunder
# -----------------------
# Weather in Karkala on 2023-05-25:
# Temperature: 28.5°C
# Humidity: 77.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-05-26:
# Temperature: 29.7°C
# Humidity: 69.0%
# Weather description: Thundery outbreaks possible
# -----------------------
# Weather in Karkala on 2023-05-27:
# Temperature: 29.6°C
# Humidity: 70.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-05-28:
# Temperature: 30.7°C
# Humidity: 69.0%
# Weather description: Thundery outbreaks possible
# -----------------------
# Weather in Karkala on 2023-05-29:
# Temperature: 29.8°C
# Humidity: 70.0%
# Weather description: Patchy light rain with thunder
# -----------------------
# Weather in Karkala on 2023-05-30:
# Temperature: 30.1°C
# Humidity: 73.0%
# Weather description: Thundery outbreaks possible
# -----------------------
# Weather in Karkala on 2023-05-31:
# Temperature: 28.6°C
# Humidity: 70.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-06-01:
# Temperature: 28.7°C
# Humidity: 77.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-06-02:
# Temperature: 29.1°C
# Humidity: 75.0%
# Weather description: Thundery outbreaks possible
# -----------------------
# Weather in Karkala on 2023-06-03:
# Temperature: 30.4°C
# Humidity: 71.0%
# Weather description: Partly cloudy
# -----------------------
# Weather in Karkala on 2023-06-04:
# Temperature: 29.9°C
# Humidity: 70.0%
# Weather description: Light rain shower
# -----------------------
# Weather in Karkala on 2023-06-05:
# Temperature: 29.3°C
# Humidity: 73.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-06-06:
# Temperature: 28.6°C
# Humidity: 75.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-06-07:
# Temperature: 29.0°C
# Humidity: 76.0%
# Weather description: Light rain shower
# -----------------------
# Weather in Karkala on 2023-06-08:
# Temperature: 28.7°C
# Humidity: 75.0%
# Weather description: Patchy rain possible
# -----------------------
# Weather in Karkala on 2023-06-09:
# Temperature: 28.5°C
# Humidity: 77.0%
# Weather description: Torrential rain shower
# -----------------------
# Weather in Karkala on 2023-06-10:
# Temperature: 28.0°C
# Humidity: 78.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-06-11:
# Temperature: 28.2°C
# Humidity: 77.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-06-12:
# Temperature: 28.3°C
# Humidity: 78.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-06-13:
# Temperature: 28.3°C
# Humidity: 78.0%
# Weather description: Light rain shower
# -----------------------
# Weather in Karkala on 2023-06-14:
# Temperature: 28.1°C
# Humidity: 79.0%
# Weather description: Moderate or heavy rain shower
# -----------------------
# Weather in Karkala on 2023-06-15:
# Temperature: 28.7°C
# Humidity: 75.0%
# Weather description: Light rain shower
# -----------------------
# Weather in Karkala on 2023-06-16:
# Temperature: 29.2°C
# Humidity: 72.0%
# Weather description: Patchy rain possible
# -----------------------

# %%
import requests
import csv
from datetime import datetime, timedelta

def get_weather_data(api_key, city, start_date, end_date):
    base_url = f"http://api.weatherapi.com/v1/history.json?key={api_key}&q={city}&dt={start_date}&end_dt={end_date}"
    response = requests.get(base_url)
    data = response.json()

    if "error" in data:
        print(f"Error occurred: {data['error']['message']}")
    else:
        forecast_days = data["forecast"]["forecastday"]
        for day in forecast_days:
            date = day["date"]
            temperature = day["day"]["avgtemp_c"]
            humidity = day["day"]["avghumidity"]
            weather_description = day["day"]["condition"]["text"]

            # Store weather data in CSV file
            with open("weather_data.csv", mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([date, temperature, humidity, weather_description])

# API key for WeatherAPI (replace with your own key)
api_key = "8779239f369845b7bb8102601231606"

# City for which you want to fetch weather data
city = "Karkala"

# Calculate start and end dates for the previous one month
end_date = datetime.now().strftime("%Y-%m-%d")
start_date = (datetime.now() - timedelta(days=30)).strftime("%Y-%m-%d")

# Call the function to get weather data and store it in CSV file
get_weather_data(api_key, city, start_date, end_date)

# %%
#loading csv file
import pandas as pd
df=pd.read_csv('weather_data.csv')
df.head()
# Out:
# C:\Users\Disha\anaconda3\lib\site-packages\pandas\_testing.py:24: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.  (This may have returned Python scalars in past versions.
#   import pandas._libs.testing as _testing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1c798d27f0b4> in <module>
#       1 #loading csv file
# ----> 2 import pandas as pd
#       3 df=pd.read_csv('weather_data.csv')
#       4 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     178
#     179 from pandas.util._tester import test
# --> 180 import pandas.testing
#     181 import pandas.arrays
#     182
#
# ~\anaconda3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# ~\anaconda3\lib\site-packages\pandas\_testing.py in <module>
#      22 )
#      23
# ---> 24 import pandas._libs.testing as _testing
#      25 from pandas._typing import FilePathOrBuffer, FrameOrSeries
#      26 from pandas.compat import _get_lzma_file, _import_lzma
#
# pandas\_libs\testing.pyx in init pandas._libs.testing()
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     282             return Tester
#     283
# --> 284         raise AttributeError("module {!r} has no attribute "
#     285                              "{!r}".format(__name__, attr))
#     286
#
# AttributeError: module 'numpy' has no attribute 'bool'

# %%
# Create feature set and target variable
X=df.drop(['Partly cloudy'], axis=1)
y=df['Partly cloudy']
X.info()

# %%
# Encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform(y)
# Out:
# array([4, 2, 4, 4, 4, 3, 3, 1, 5, 4, 5, 3, 5, 4, 4, 5, 2, 0, 4, 1, 0, 4,
#        6, 1, 1, 1, 0, 1, 0, 4])

# %%
# Creation of training and testing set
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
# import a model
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
# Perform a training
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Perform a training
# ----> 2 model.fit(X_train, y_train)
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\sklearn\tree\_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     184 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186 X, y = self._validate_data(
#     187     X, y, validate_separately=(check_X_params, check_y_params)
#     188 )
#     189 if issparse(X):
#     190     X.sort_indices()
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\sklearn\base.py:549, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     547 if "estimator" not in check_X_params:
#     548     check_X_params = {**default_check_params, **check_X_params}
# --> 549 X = check_array(X, input_name="X", **check_X_params)
#     550 if "estimator" not in check_y_params:
#     551     check_y_params = {**default_check_params, **check_y_params}
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\sklearn\utils\validation.py:877, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     875         array = xp.astype(array, dtype, copy=False)
#     876     else:
# --> 877         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     878 except ComplexWarning as complex_warning:
#     879     raise ValueError(
#     880         "Complex data not supported\n{}\n".format(array)
#     881     ) from complex_warning
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File ~\anaconda3\envs\AdvancedML\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '2023-06-03'
